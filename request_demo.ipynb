# %%
import requests
url ='http://127.0.0.1:7000/get_info'
requests.post(url=url,json={"tname":"工商银行","save_path":'./results'}).json()
# Out:
# {'message': 'Data successfully fetched and saved to ./results\\工商银行_20250914.md.',
# ...
